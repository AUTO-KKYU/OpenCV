# %%
import numpy as np 
import matplotlib.pyplot as plt 
from PIL import Image 
import cv2

# %% [markdown]
# - img 파일을 opencv로 읽어보면 저절로 numpy array가 되어 있음

# %%
img = cv2.imread('/home/kkyu/amr_ws/opencv/data/tree.bmp')
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# - 주의사항 path / 파일 존재 여부

# %%
tmp = cv2.imread('./melonglong.jpg')
type(tmp)
# Out:
# [ WARN:0@380.135] global loadsave.cpp:248 findDecoder imread_('./melonglong.jpg'): can't open/read file: check file path/integrity
# NoneType

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %% [markdown]
# ### matplotlib이 RGB 순서로 읽는데 OpenCV는 BGR 순서로 읽음

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %% [markdown]
# - 이미지 파일을 읽을 때 부터 Gray로 읽기

# %%
img_gray = cv2.imread('/home/kkyu/amr_ws/opencv/data/tree.bmp', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap = 'gray')

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %% [markdown]
# - 큰 이미지를 작게 줄여서 보기

# %%
new_img = cv2.resize(fix_img, (800,600))
plt.imshow(new_img)

# %% [markdown]
# - 상하 반전

# %%
plt.imshow(cv2.flip(fix_img, 0))

# %% [markdown]
# - 좌우 반전

# %%
plt.imshow(cv2.flip(fix_img, 1))

# %% [markdown]
# - 상하 좌우 둘 다

# %%
plt.imshow(cv2.flip(fix_img, -1))

# %%
plt.imshow(img_gray, cmap = 'gray')

# %% [markdown]
# - 파일 저장

# %%
cv2.imwrite('/home/kkyu/amr_ws/opencv/data/tree_gray.bmp', img_gray)
# Out:
# True
